# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.DataFrame(np.random.rand(1000,1), index = pd.date_range('2025-11-06',periods = 1000) , columns=['data'])
df
# Out:
#                 data
# 2025-11-06  0.193751
# 2025-11-07  0.225223
# 2025-11-08  0.498912
# 2025-11-09  0.319512
# 2025-11-10  0.416265
# ...              ...
# 2028-07-28  0.526421
# 2028-07-29  0.254708
# 2028-07-30  0.018481
# 2028-07-31  0.773929
# 2028-08-01  0.675744
#
# [1000 rows x 1 columns]

# %%
df.plot()
plt.show()

# %%
df.data.cumsum().plot()
plt.show()

# %%
df.data.cumsum()
# Out:
# 2025-11-06      0.322403
# 2025-11-07      0.661389
# 2025-11-08      1.139357
# 2025-11-09      1.266576
# 2025-11-10      1.270723
#                  ...
# 2028-07-28    507.955973
# 2028-07-29    508.891252
# 2028-07-30    509.096669
# 2028-07-31    509.995916
# 2028-08-01    510.686973
# Freq: D, Name: data, Length: 1000, dtype: float64

# %%
df
# Out:
#                 data
# 2025-11-06  0.322403
# 2025-11-07  0.338986
# 2025-11-08  0.477969
# 2025-11-09  0.127219
# 2025-11-10  0.004147
# ...              ...
# 2028-07-28  0.523748
# 2028-07-29  0.935279
# 2028-07-30  0.205417
# 2028-07-31  0.899247
# 2028-08-01  0.691057
#
# [1000 rows x 1 columns]

# %%
df['data1'] = df.data.cumsum()

# %%
df
# Out:
#                 data       data1
# 2025-11-06  0.322403    0.322403
# 2025-11-07  0.338986    0.661389
# 2025-11-08  0.477969    1.139357
# 2025-11-09  0.127219    1.266576
# 2025-11-10  0.004147    1.270723
# ...              ...         ...
# 2028-07-28  0.523748  507.955973
# 2028-07-29  0.935279  508.891252
# 2028-07-30  0.205417  509.096669
# 2028-07-31  0.899247  509.995916
# 2028-08-01  0.691057  510.686973
#
# [1000 rows x 2 columns]

# %%
df['data2'] = df['data'].apply(lambda x:x*3)
df
# Out:
#                 data       data1     data2
# 2025-11-06  0.322403    0.322403  0.967208
# 2025-11-07  0.338986    0.661389  1.016958
# 2025-11-08  0.477969    1.139357  1.433906
# 2025-11-09  0.127219    1.266576  0.381657
# 2025-11-10  0.004147    1.270723  0.012442
# ...              ...         ...       ...
# 2028-07-28  0.523748  507.955973  1.571245
# 2028-07-29  0.935279  508.891252  2.805837
# 2028-07-30  0.205417  509.096669  0.616252
# 2028-07-31  0.899247  509.995916  2.697740
# 2028-08-01  0.691057  510.686973  2.073172
#
# [1000 rows x 3 columns]

# %%
df.plot()
plt.show()

# %%
df.plot(figsize=(10,10))  # For bigger size
plt.show()

# %%
df1 = sns.load_dataset('iris')
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.plot()
plt.show()

# %%
df1.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df1.plot(figsize=(10,10), title='IRIS Data')
plt.show()

# %%
gf = df1.plot( title='IRIS Data')
gf.set_xlabel("This is my x axis")
gf.set_ylabel('This is my y axis')
plt.show()

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.iloc[0][0:4].plot()
plt.show()

# %%
df1.iloc[0][0:4].plot(kind='bar')
plt.show()

# %%
df2 = sns.load_dataset('titanic')
df2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df2['pclass'].plot()
plt.show()

# %%
df2['pclass'].plot(kind='bar')
plt.show()

# %%
df3 = pd.DataFrame(np.random.rand(10,4), columns=['a','b','c','d'])
df3
# Out:
#           a         b         c         d
# 0  0.778694  0.076269  0.498579  0.547941
# 1  0.153856  0.854371  0.960950  0.223194
# 2  0.798833  0.575384  0.980883  0.991157
# 3  0.035444  0.565183  0.089486  0.936651
# 4  0.910807  0.258344  0.796514  0.849611
# 5  0.100027  0.289575  0.345155  0.965585
# 6  0.455230  0.773559  0.670576  0.568589
# 7  0.831581  0.696484  0.446543  0.786756
# 8  0.050846  0.320202  0.202723  0.498262
# 9  0.844574  0.013921  0.895370  0.246507

# %%
df3.plot.bar()
plt.show()

# %%
df3.plot.barh()
plt.show()

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.plot.hist()
plt.show()

# %%
df1.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df1['sepal_length'].plot.hist(color='r')
plt.show()

# %%
df1.plot(kind='hist', stacked=True, bins=100, title="Histogram of IRIS")
plt.show()

# %%
df1.plot(kind='hist', stacked=True, bins=100, title="Histogram of IRIS", orientation='horizontal')
plt.show()

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.hist(figsize=(10,10))
plt.show()

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.plot.scatter(x='sepal_width', y='petal_width')
plt.show()

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
 df1.plot.scatter(x='sepal_length', y='petal_length',color='r')
plt.show()
# Out:
#   Cell In[43], line 1
#     df1.plot.scatter(x='sepal_length', y='petal_length',color='r')
#     ^
# IndentationError: unexpected indent

# %%
df1.plot.scatter(x='sepal_length', y='petal_length',c='petal_width')
plt.show()

# %%
df1.plot.hexbin(x='sepal_length', y='petal_length')
plt.show()

# %%
df1.plot.hexbin(x='sepal_length', y='petal_length', gridsize=10)
plt.show()

# %%
d = df.iloc[0]
d
# Out:
# data     0.322403
# data1    0.322403
# data2    0.967208
# Name: 2025-11-06 00:00:00, dtype: float64

# %%
d.plot.pie()
plt.show()

# %%
pd.plotting.scatter_matrix(df1,figsize=(10,10))
plt.show()

# %%
pd.plotting.scatter_matrix(df1,figsize=(10,10),diagonal='kde')
plt.show()

# %%
df['data'].plot()
plt.show()

# %%
df['data'].plot(style='y--')
plt.show()

# %%
df['data'].plot(style='g*', legend=True, label="Satya")
plt.show()

# %%
np.__version__
# Out:
# '2.3.4'

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# !pip install plotly

# %%
import plotly 
plotly.__version__
# Out:
# '6.4.0'

# %%
# !pip install --upgrade plotly
# Out:
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.9 MB 2.4 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.0/9.9 MB 2.0 MB/s eta 0:00:05
#    ------ --------------------------------- 1.6/9.9 MB 1.8 MB/s eta 0:00:05
#    -------- ------------------------------- 2.1/9.9 MB 2.1 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.9/9.9 MB 2.3 MB/s eta 0:00:04
#    ------------- -------------------------- 3.4/9.9 MB 2.4 MB/s eta 0:00:03
#    ---------------- ----------------------- 4.2/9.9 MB 2.5 MB/s eta 0:00:03
#    -------------------- ------------------- 5.0/9.9 MB 2.7 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.8/9.9 MB 2.7 MB/s eta 0:00:02
# ...

# %%
import plotly.express as px
import plotly.graph_objects as go

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
fig = px.scatter(df1, x="sepal_width", y="sepal_length", color="species", title="Iris Dataset Scatter Plot")
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_17.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
plotly.__version__
# Out:
# '6.4.0'

# %%
import plotly.io as pio
pio.renderers.default = 'iframe_connected'

# %%
fig = px.line(df1,  color="species", title="Iris Dataset Scatter Plot")
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_20.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
fig = px.line(df1, color="species")
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_24.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
df2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
fig = px.scatter(df2, x="fare", y="age", title="Titanic Data")
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_31.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
fig = px.line(df2, x="fare", y="age", title="Titanic Data")
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_32.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
