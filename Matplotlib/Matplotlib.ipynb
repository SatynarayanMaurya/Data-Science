# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.DataFrame(np.random.rand(1000,1), index = pd.date_range('2025-11-06',periods = 1000) , columns=['data'])
df
# Out:
#                 data
# 2025-11-06  0.701471
# 2025-11-07  0.446919
# 2025-11-08  0.230139
# 2025-11-09  0.820468
# 2025-11-10  0.879199
# ...              ...
# 2028-07-28  0.200527
# 2028-07-29  0.731531
# 2028-07-30  0.524748
# 2028-07-31  0.571136
# 2028-08-01  0.348524
#
# [1000 rows x 1 columns]

# %%
df.plot()
plt.show()

# %%
df.data.cumsum().plot()
plt.show()

# %%
df.data.cumsum()
# Out:
# 2025-11-06      0.701471
# 2025-11-07      1.148390
# 2025-11-08      1.378530
# 2025-11-09      2.198998
# 2025-11-10      3.078197
#                  ...
# 2028-07-28    504.251727
# 2028-07-29    504.983258
# 2028-07-30    505.508006
# 2028-07-31    506.079142
# 2028-08-01    506.427666
# Freq: D, Name: data, Length: 1000, dtype: float64

# %%
df
# Out:
#                 data
# 2025-11-06  0.701471
# 2025-11-07  0.446919
# 2025-11-08  0.230139
# 2025-11-09  0.820468
# 2025-11-10  0.879199
# ...              ...
# 2028-07-28  0.200527
# 2028-07-29  0.731531
# 2028-07-30  0.524748
# 2028-07-31  0.571136
# 2028-08-01  0.348524
#
# [1000 rows x 1 columns]

# %%
df['data1'] = df.data.cumsum()

# %%
df
# Out:
#                 data       data1
# 2025-11-06  0.701471    0.701471
# 2025-11-07  0.446919    1.148390
# 2025-11-08  0.230139    1.378530
# 2025-11-09  0.820468    2.198998
# 2025-11-10  0.879199    3.078197
# ...              ...         ...
# 2028-07-28  0.200527  504.251727
# 2028-07-29  0.731531  504.983258
# 2028-07-30  0.524748  505.508006
# 2028-07-31  0.571136  506.079142
# 2028-08-01  0.348524  506.427666
#
# [1000 rows x 2 columns]

# %%
df['data2'] = df['data'].apply(lambda x:x*3)
df
# Out:
#                 data       data1     data2
# 2025-11-06  0.701471    0.701471  2.104413
# 2025-11-07  0.446919    1.148390  1.340757
# 2025-11-08  0.230139    1.378530  0.690418
# 2025-11-09  0.820468    2.198998  2.461404
# 2025-11-10  0.879199    3.078197  2.637597
# ...              ...         ...       ...
# 2028-07-28  0.200527  504.251727  0.601582
# 2028-07-29  0.731531  504.983258  2.194592
# 2028-07-30  0.524748  505.508006  1.574244
# 2028-07-31  0.571136  506.079142  1.713409
# 2028-08-01  0.348524  506.427666  1.045571
#
# [1000 rows x 3 columns]

# %%
df.plot()
plt.show()

# %%
df.plot(figsize=(10,10))  # For bigger size
plt.show()

# %%
df1 = sns.load_dataset('iris')
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.plot()
plt.show()

# %%
df1.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df1.plot(figsize=(10,10), title='IRIS Data')
plt.show()

# %%
gf = df1.plot( title='IRIS Data')
gf.set_xlabel("This is my x axis")
gf.set_ylabel('This is my y axis')
plt.show()

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.iloc[0][0:4].plot()
plt.show()

# %%
df1.iloc[0][0:4].plot(kind='bar')
plt.show()

# %%
df2 = sns.load_dataset('titanic')
df2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
df2['pclass'].plot()
plt.show()

# %%
df2['pclass'].plot(kind='bar')
plt.show()

# %%
df3 = pd.DataFrame(np.random.rand(10,4), columns=['a','b','c','d'])
df3
# Out:
#           a         b         c         d
# 0  0.334903  0.993463  0.531451  0.935467
# 1  0.112879  0.601368  0.129407  0.854834
# 2  0.613149  0.242194  0.358220  0.988341
# 3  0.893723  0.486364  0.792995  0.762183
# 4  0.756693  0.145160  0.981612  0.871308
# 5  0.769543  0.867166  0.814344  0.298252
# 6  0.757054  0.615689  0.069143  0.331153
# 7  0.526022  0.354341  0.567825  0.836749
# 8  0.684990  0.316951  0.470081  0.161822
# 9  0.598852  0.023519  0.734669  0.118413

# %%
df3.plot.bar()
plt.show()

# %%
df3.plot.barh()
plt.show()

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.plot.hist()
plt.show()

# %%
df1.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df1['sepal_length'].plot.hist(color='r')
plt.show()

# %%
df1.plot(kind='hist', stacked=True, bins=100, title="Histogram of IRIS")
plt.show()

# %%
df1.plot(kind='hist', stacked=True, bins=100, title="Histogram of IRIS", orientation='horizontal')
plt.show()

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.hist(figsize=(10,10))
plt.show()

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.plot.scatter(x='sepal_width', y='petal_width')
plt.show()

# %%
 df1.plot.scatter(x='sepal_length', y='petal_length',color='#13E8F2')
plt.show()

# %%
df1.plot.scatter(x='sepal_length', y='petal_length',c='petal_width')
plt.show()

# %%
df1.plot.hexbin(x='sepal_length', y='petal_length')
plt.show()

# %%
df1.plot.hexbin(x='sepal_length', y='petal_length', gridsize=10)
plt.show()

# %%
d = df.iloc[0]
d
# Out:
# data     0.701471
# data1    0.701471
# data2    2.104413
# Name: 2025-11-06 00:00:00, dtype: float64

# %%
d.plot.pie()
plt.show()

# %%
pd.plotting.scatter_matrix(df1,figsize=(10,10))
plt.show()

# %%
pd.plotting.scatter_matrix(df1,figsize=(10,10),diagonal='kde')
plt.show()

# %%
df['data'].plot()
plt.show()

# %%
df['data'].plot(style='y--')
plt.show()
