# %%
# !pip install pymongo dnspython

# %%
# Connection method with mongo db
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
uri = "mongodb+srv://satynarayanmaurya111_db_user:dzuBcpv5V3QY8AGY@cluster0.zgfplea.mongodb.net/?appName=Cluster0"
# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))
# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
# Another method of connecting to the mongo db
import pymongo
client = pymongo.MongoClient("mongodb+srv://satynarayanmaurya111_db_user:dzuBcpv5V3QY8AGY@cluster0.zgfplea.mongodb.net/?appName=Cluster0")
client
# Out:
# MongoClient(host=['ac-ql9wfph-shard-00-00.zgfplea.mongodb.net:27017', 'ac-ql9wfph-shard-00-02.zgfplea.mongodb.net:27017', 'ac-ql9wfph-shard-00-01.zgfplea.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, appname='Cluster0', authsource='admin', replicaset='atlas-kp11yg-shard-0', tls=True)

# %%
# Create the database 
DB_URL = "first_database"
connection = client[DB_URL]
connection
# Out:
# Database(MongoClient(host=['ac-ql9wfph-shard-00-00.zgfplea.mongodb.net:27017', 'ac-ql9wfph-shard-00-02.zgfplea.mongodb.net:27017', 'ac-ql9wfph-shard-00-01.zgfplea.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, appname='Cluster0', authsource='admin', replicaset='atlas-kp11yg-shard-0', tls=True), 'first_database')

# %%
# Create the tables or collection 
schema = "students"
collection = connection[schema]
collection
# Out:
# Collection(Database(MongoClient(host=['ac-ql9wfph-shard-00-00.zgfplea.mongodb.net:27017', 'ac-ql9wfph-shard-00-02.zgfplea.mongodb.net:27017', 'ac-ql9wfph-shard-00-01.zgfplea.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, appname='Cluster0', authsource='admin', replicaset='atlas-kp11yg-shard-0', tls=True), 'first_database'), 'students')

# %%
# Insert the data to this collection 
student_record = {
    'name':"Satynarayan Maurya",
    'rollNo':21150,
    'college':"IET AYODHYA"
}
collection.insert_one(student_record)
# Out:
# InsertOneResult(ObjectId('69059d53f9f4c9550637b895'), acknowledged=True)

# %%
# Another recored with more key and pairs in the same collection 
student_record = {
    'name':"Manoj Maurya",
    'rollNo':21151,
    'college':"IET AYODHYA",
    'course':"B.tech",
    'Branch':"CSE",
    'availableBranch':["IT","CSE","ECE","EE"]
}
collection.insert_one(student_record)
# Out:
# InsertOneResult(ObjectId('69059de7f9f4c9550637b896'), acknowledged=True)

# %%
# Insert multiple record at a time 
records = [
    {
        "name":"satya1",
        "email":"satya1@gmail.com"
    },
    {
        "name":"satya2",
        "email":"satya2@gmail.com",
        "skills":["C","C++","Python","Javascript"]
        
    },
    {
        "name":"satya3",
        "email":"satya3@gmail.com",
        "projects":{"E-commerce":"ShopNext","AI Chatbot":"Intelliq"}
    },
    {
        "name":"satya4",
        "email":"satya4@gmail.com",
        "experience":{"Software Developer":"6 Month"},
        "skills":["Node js","Express js","Mongo DB"]
    },
    {
        "name":"satya5",
        "email":"satya5@gmail.com",
        "education":"IET Ayodhya"
    },
]
collection.insert_many(records)
# Out:
# InsertManyResult([ObjectId('6905afdaf9f4c9550637b897'), ObjectId('6905afdaf9f4c9550637b898'), ObjectId('6905afdaf9f4c9550637b899'), ObjectId('6905afdaf9f4c9550637b89a'), ObjectId('6905afdaf9f4c9550637b89b')], acknowledged=True)

# %%
# Make another collection
collection_name = "faculties"
collection_faculty = connection[collection_name]

# %%
# Insert data to the new collection 
data = {"name":"abcd","email":"abcd@gmail.com"}
collection_faculty.insert_one(data)
# Out:
# InsertOneResult(ObjectId('6905b0d8f9f4c9550637b89d'), acknowledged=True)

# %%
# Insert Many into faculty
records =[
    {
        "_id":1,
        "name":"Aashish Pandey",
        "faculty":"CSE"
    },
    {
        "_id":2,
        "name":"Avadhesh Dixit",
        "faculty":"CSE"
    },
    {
        "_id":3,
        "name":"Avadhesh Yadav",
        "faculty":"CSE"
    },
    {
        "_id":4,
        "name":"Piyush Pandey",
        "faculty":"CSE"
    },
    {
        "_id":5,
        "name":"Nidhi Ma'am",
        "faculty":"CSE"
    },
    {
        "_id":6,
        "name":"Shobhit Pandey",
        "faculty":"CSE"
    },
]
collection_faculty.insert_many(records)
# Out:
# InsertManyResult([1, 2, 3, 4, 5, 6], acknowledged=True)

# %%
# Now getting data from DB
collection_faculty.find_one()
# Out:
# {'_id': ObjectId('6905b0d8f9f4c9550637b89d'),
#  'name': 'abcd',
#  'email': 'abcd@gmail.com'}

# %%
for i in collection_faculty.find({"_id":{"$gt":2}}):
    print(i)
# Out:
# {'_id': 3, 'name': 'Avadhesh Yadav', 'faculty': 'CSE'}
# {'_id': 4, 'name': 'Piyush Pandey', 'faculty': 'CSE'}
# {'_id': 5, 'name': "Nidhi Ma'am", 'faculty': 'CSE'}
# {'_id': 6, 'name': 'Shobhit Pandey', 'faculty': 'CSE'}

# %%
for i in collection_faculty.find({"_id":{"$gte":2}}):
    print(i)
# Out:
# {'_id': 2, 'name': 'Avadhesh Dixit', 'faculty': 'CSE'}
# {'_id': 3, 'name': 'Avadhesh Yadav', 'faculty': 'CSE'}
# {'_id': 4, 'name': 'Piyush Pandey', 'faculty': 'CSE'}
# {'_id': 5, 'name': "Nidhi Ma'am", 'faculty': 'CSE'}
# {'_id': 6, 'name': 'Shobhit Pandey', 'faculty': 'CSE'}

# %%
for i in collection_faculty.find({"_id":{"$ne":2}}):
    print(i)
# Out:
# {'_id': 1, 'name': 'Aashish Pandey', 'faculty': 'CSE'}
# {'_id': 3, 'name': 'Avadhesh Yadav', 'faculty': 'CSE'}
# {'_id': 4, 'name': 'Piyush Pandey', 'faculty': 'CSE'}
# {'_id': 5, 'name': "Nidhi Ma'am", 'faculty': 'CSE'}
# {'_id': 6, 'name': 'Shobhit Pandey', 'faculty': 'CSE'}
# {'_id': ObjectId('6905b0d8f9f4c9550637b89d'), 'name': 'abcd', 'email': 'abcd@gmail.com'}

# %%
# Delete data from the collection 
collection_faculty.delete_one({"_id":3})
# Out:
# DeleteResult({'n': 1, 'electionId': ObjectId('7fffffff00000000000000c6'), 'opTime': {'ts': Timestamp(1761981084, 5), 't': 198}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1761981084, 5), 'signature': {'hash': b'\xfa)Y8\xe0\xf6\x81\xd6\xc8\xf8z+\xf4\xae}\xe4\xd3\x83\xda\x7f', 'keyId': 7504702214359744518}}, 'operationTime': Timestamp(1761981084, 5)}, acknowledged=True)

# %%
for i in collection_faculty.find():
    print(i)
# Out:
# {'_id': ObjectId('6905b0d8f9f4c9550637b89d'), 'name': 'abcd', 'email': 'abcd@gmail.com'}
# {'_id': 1, 'name': 'Aashish Pandey', 'faculty': 'CSE'}
# {'_id': 2, 'name': 'Avadhesh Dixit', 'faculty': 'CSE'}
# {'_id': 4, 'name': 'Piyush Pandey', 'faculty': 'CSE'}
# {'_id': 5, 'name': "Nidhi Ma'am", 'faculty': 'CSE'}
# {'_id': 6, 'name': 'Shobhit Pandey', 'faculty': 'CSE'}

# %%
collection_faculty.delete_one({"_id":{"$lt":3}})
# Out:
# DeleteResult({'n': 1, 'electionId': ObjectId('7fffffff00000000000000c6'), 'opTime': {'ts': Timestamp(1761981133, 3), 't': 198}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1761981133, 3), 'signature': {'hash': b'#\x9f\xc2l\x04\x97\xdb\xf0\xbby}\xbb\xf7\xc7%\x0e\x89\x87T\x84', 'keyId': 7504702214359744518}}, 'operationTime': Timestamp(1761981133, 3)}, acknowledged=True)

# %%
for i in collection_faculty.find({"_id":{"$ne":2}}):
    print(i)
# Out:
# {'_id': 4, 'name': 'Piyush Pandey', 'faculty': 'CSE'}
# {'_id': 5, 'name': "Nidhi Ma'am", 'faculty': 'CSE'}
# {'_id': 6, 'name': 'Shobhit Pandey', 'faculty': 'CSE'}
# {'_id': ObjectId('6905b0d8f9f4c9550637b89d'), 'name': 'abcd', 'email': 'abcd@gmail.com'}

# %%
# Now Update the existing 
collection_faculty.update_one({"_id":5},{"$set":{"name":"Nidhi Mam"}})
# Out:
# UpdateResult({'n': 1, 'electionId': ObjectId('7fffffff00000000000000c6'), 'opTime': {'ts': Timestamp(1761981302, 1), 't': 198}, 'nModified': 1, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1761981302, 1), 'signature': {'hash': b'\xb9\x07\xb0I\x8f\xee)^A\x8dr_- "G\x13\xe4\x90\x98', 'keyId': 7504702214359744518}}, 'operationTime': Timestamp(1761981302, 1), 'updatedExisting': True}, acknowledged=True)

# %%
for i in collection_faculty.find():
    print(i)
# Out:
# {'_id': ObjectId('6905b0d8f9f4c9550637b89d'), 'name': 'abcd', 'email': 'abcd@gmail.com'}
# {'_id': 2, 'name': 'Avadhesh Dixit', 'faculty': 'CSE'}
# {'_id': 4, 'name': 'Piyush Pandey', 'faculty': 'CSE'}
# {'_id': 5, 'name': 'Nidhi Mam', 'faculty': 'CSE'}
# {'_id': 6, 'name': 'Shobhit Pandey', 'faculty': 'CSE'}

# %%
# Update many
collection_faculty.update_many({"_id":{"$gt":4}},{"$set":{"faculty":"Computer Science & Engineering"}})
# Out:
# UpdateResult({'n': 2, 'electionId': ObjectId('7fffffff00000000000000c6'), 'opTime': {'ts': Timestamp(1761981436, 2), 't': 198}, 'nModified': 2, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1761981436, 2), 'signature': {'hash': b'A"\x95\xa3\xfc\x06\x84\xfa\xe9\x1a]\x97\xc89S\xd2\xa5\xc0\xbf\x03', 'keyId': 7504702214359744518}}, 'operationTime': Timestamp(1761981436, 2), 'updatedExisting': True}, acknowledged=True)

# %%
for i in collection_faculty.find():
    print(i)
# Out:
# {'_id': ObjectId('6905b0d8f9f4c9550637b89d'), 'name': 'abcd', 'email': 'abcd@gmail.com'}
# {'_id': 2, 'name': 'Avadhesh Dixit', 'faculty': 'CSE'}
# {'_id': 4, 'name': 'Piyush Pandey', 'faculty': 'CSE'}
# {'_id': 5, 'name': 'Nidhi Mam', 'faculty': 'Computer Science & Engineering'}
# {'_id': 6, 'name': 'Shobhit Pandey', 'faculty': 'Computer Science & Engineering'}
