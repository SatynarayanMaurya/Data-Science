# %%
import pandas as pd

# %%
data = pd.read_csv("cricket_players.csv")
data
# Out:
#      player_id          player_name    batting_hand       booling_skill  \
# 0            1          Jorge Jones  Right-hand bat  Right-arm offbreak
# 1            2          James Clark  Right-hand bat                 NaN
# 2            3       Brittney Jones  Right-hand bat                 NaN
# 3            4         Melissa Owen  Right-hand bat      Right-arm fast
# 4            5      Heather Stewart  Right-hand bat    Right-arm medium
# ..         ...                  ...             ...                 ...
# 195        196      Jamie Gutierrez  Right-hand bat    Right-arm medium
# 196        197      Holly Hernandez   Left-hand bat     Left-arm medium
# 197        198  Christopher Ramirez  Right-hand bat   Left-arm orthodox
# 198        199         Todd Skinner   Left-hand bat      Right-arm fast
# 199        200      Daniel Martinez   Left-hand bat            Legbreak
#
#           country         dob
# 0       Australia  25-01-1992
# 1    South Africa  05-04-2006
# ...

# %%
data.head()
# Out:
#    player_id      player_name    batting_hand       booling_skill  \
# 0          1      Jorge Jones  Right-hand bat  Right-arm offbreak
# 1          2      James Clark  Right-hand bat                 NaN
# 2          3   Brittney Jones  Right-hand bat                 NaN
# 3          4     Melissa Owen  Right-hand bat      Right-arm fast
# 4          5  Heather Stewart  Right-hand bat    Right-arm medium
#
#         country         dob
# 0     Australia  25-01-1992
# 1  South Africa  05-04-2006
# 2     Sri Lanka  18-06-1998
# 3   West Indies  06-04-2000
# 4     Sri Lanka  07-08-1993

# %%
# Head default show the top 5 rows but we can modify according to us like
data.head(10)
# Out:
#    player_id        player_name    batting_hand       booling_skill  \
# 0          1        Jorge Jones  Right-hand bat  Right-arm offbreak
# 1          2        James Clark  Right-hand bat                 NaN
# 2          3     Brittney Jones  Right-hand bat                 NaN
# 3          4       Melissa Owen  Right-hand bat      Right-arm fast
# 4          5    Heather Stewart  Right-hand bat    Right-arm medium
# 5          6       Debra Holder   Left-hand bat       Left-arm fast
# 6          7       Daniel Smith  Right-hand bat   Left-arm orthodox
# 7          8       Mary Hensley  Right-hand bat   Left-arm orthodox
# 8          9        Amy Mathews  Right-hand bat     Left-arm medium
# 9         10  Heather Hernandez   Left-hand bat  Right-arm offbreak
#
#         country         dob
# 0     Australia  25-01-1992
# 1  South Africa  05-04-2006
# 2     Sri Lanka  18-06-1998
# 3   West Indies  06-04-2000
# 4     Sri Lanka  07-08-1993
# 5       England  18-12-2005
# ...

# %%
data.head(2)
# Out:
#    player_id  player_name    batting_hand       booling_skill       country  \
# 0          1  Jorge Jones  Right-hand bat  Right-arm offbreak     Australia
# 1          2  James Clark  Right-hand bat                 NaN  South Africa
#
#           dob
# 0  25-01-1992
# 1  05-04-2006

# %%
# Like the head there is tail also which give the rows from the last in default they provide 5 rows but we can modify that also
data.tail()
# Out:
#      player_id          player_name    batting_hand      booling_skill  \
# 195        196      Jamie Gutierrez  Right-hand bat   Right-arm medium
# 196        197      Holly Hernandez   Left-hand bat    Left-arm medium
# 197        198  Christopher Ramirez  Right-hand bat  Left-arm orthodox
# 198        199         Todd Skinner   Left-hand bat     Right-arm fast
# 199        200      Daniel Martinez   Left-hand bat           Legbreak
#
#          country         dob
# 195     Pakistan  15-06-1997
# 196      England  14-04-1994
# 197  New Zealand  22-05-1990
# 198    Sri Lanka  21-10-2004
# 199     Pakistan  04-01-2005

# %%
data.tail(3)
# Out:
#      player_id          player_name    batting_hand      booling_skill  \
# 197        198  Christopher Ramirez  Right-hand bat  Left-arm orthodox
# 198        199         Todd Skinner   Left-hand bat     Right-arm fast
# 199        200      Daniel Martinez   Left-hand bat           Legbreak
#
#          country         dob
# 197  New Zealand  22-05-1990
# 198    Sri Lanka  21-10-2004
# 199     Pakistan  04-01-2005

# %%
# Some modification when we read the csv file as in default python read the first row as a header 
data1 = pd.read_csv("cricket_players.csv",sep=",",header=None,)
data1
# Out:
#              0                    1               2                   3  \
# 0    player_id          player_name    batting_hand       booling_skill
# 1            1          Jorge Jones  Right-hand bat  Right-arm offbreak
# 2            2          James Clark  Right-hand bat                 NaN
# 3            3       Brittney Jones  Right-hand bat                 NaN
# 4            4         Melissa Owen  Right-hand bat      Right-arm fast
# ..         ...                  ...             ...                 ...
# 196        196      Jamie Gutierrez  Right-hand bat    Right-arm medium
# 197        197      Holly Hernandez   Left-hand bat     Left-arm medium
# 198        198  Christopher Ramirez  Right-hand bat   Left-arm orthodox
# 199        199         Todd Skinner   Left-hand bat      Right-arm fast
# 200        200      Daniel Martinez   Left-hand bat            Legbreak
#
#                 4           5
# 0         country         dob
# 1       Australia  25-01-1992
# ...

# %%
# As here the header is change now and they give as their index we can modify it also
data1 = pd.read_csv("cricket_players.csv",sep=",",header=None,names=['a','b','c','d','e','f'])
data1
# Out:
#              a                    b               c                   d  \
# 0    player_id          player_name    batting_hand       booling_skill
# 1            1          Jorge Jones  Right-hand bat  Right-arm offbreak
# 2            2          James Clark  Right-hand bat                 NaN
# 3            3       Brittney Jones  Right-hand bat                 NaN
# 4            4         Melissa Owen  Right-hand bat      Right-arm fast
# ..         ...                  ...             ...                 ...
# 196        196      Jamie Gutierrez  Right-hand bat    Right-arm medium
# 197        197      Holly Hernandez   Left-hand bat     Left-arm medium
# 198        198  Christopher Ramirez  Right-hand bat   Left-arm orthodox
# 199        199         Todd Skinner   Left-hand bat      Right-arm fast
# 200        200      Daniel Martinez   Left-hand bat            Legbreak
#
#                 e           f
# 0         country         dob
# 1       Australia  25-01-1992
# ...

# %%
# Let's we have to save this csv file 
data2 = pd.read_csv("cricket_players.csv")
saveIt = data2.head(10)
saveIt.to_csv("New_Cricket_Players.csv")

# %%
ls
# Out:
#  Volume in drive D is  Volume
#  Volume Serial Number is 709E-EFA0
#
#  Directory of D:\Data Science\Pandas
#
# 02-11-2025  09:56    <DIR>          .
# 02-11-2025  09:45    <DIR>          ..
# 02-11-2025  09:47    <DIR>          .ipynb_checkpoints
# 02-11-2025  09:55            44,078 Basic.ipynb
# 02-11-2025  09:44            13,918 cricket_players.csv
# 02-11-2025  09:56               749 New_Cricket_Players.csv
#                3 File(s)         58,745 bytes
#                3 Dir(s)  23,676,588,032 bytes free

# %%
type(data2)
# Out:
# pandas.core.frame.DataFrame

# %%
data = pd.read_csv("New_Cricket_Players.csv")
data
# Out:
#    Unnamed: 0  player_id        player_name    batting_hand  \
# 0           0          1        Jorge Jones  Right-hand bat
# 1           1          2        James Clark  Right-hand bat
# 2           2          3     Brittney Jones  Right-hand bat
# 3           3          4       Melissa Owen  Right-hand bat
# 4           4          5    Heather Stewart  Right-hand bat
# 5           5          6       Debra Holder   Left-hand bat
# 6           6          7       Daniel Smith  Right-hand bat
# 7           7          8       Mary Hensley  Right-hand bat
# 8           8          9        Amy Mathews  Right-hand bat
# 9           9         10  Heather Hernandez   Left-hand bat
#
#         booling_skill       country         dob
# 0  Right-arm offbreak     Australia  25-01-1992
# 1                 NaN  South Africa  05-04-2006
# 2                 NaN     Sri Lanka  18-06-1998
# 3      Right-arm fast   West Indies  06-04-2000
# 4    Right-arm medium     Sri Lanka  07-08-1993
# ...

# %%
# Lets we have to skip some rows from the csv file that can be also done
data = pd.read_csv("New_Cricket_Players.csv",skiprows=[1,4,6])
data
# Out:
#    Unnamed: 0  player_id        player_name    batting_hand  \
# 0           1          2        James Clark  Right-hand bat
# 1           2          3     Brittney Jones  Right-hand bat
# 2           4          5    Heather Stewart  Right-hand bat
# 3           6          7       Daniel Smith  Right-hand bat
# 4           7          8       Mary Hensley  Right-hand bat
# 5           8          9        Amy Mathews  Right-hand bat
# 6           9         10  Heather Hernandez   Left-hand bat
#
#         booling_skill       country         dob
# 0                 NaN  South Africa  05-04-2006
# 1                 NaN     Sri Lanka  18-06-1998
# 2    Right-arm medium     Sri Lanka  07-08-1993
# 3   Left-arm orthodox    Bangladesh  28-12-2006
# 4   Left-arm orthodox       England  07-04-1991
# 5     Left-arm medium       England  11-04-2000
# 6  Right-arm offbreak   New Zealand  07-08-2003

# %%
# We can reset some values to NaN
data = pd.read_csv("New_Cricket_Players.csv",na_values=["James Clark","Left-arm orthodox"])
data
# Out:
#    Unnamed: 0  player_id        player_name    batting_hand  \
# 0           0          1        Jorge Jones  Right-hand bat
# 1           1          2                NaN  Right-hand bat
# 2           2          3     Brittney Jones  Right-hand bat
# 3           3          4       Melissa Owen  Right-hand bat
# 4           4          5    Heather Stewart  Right-hand bat
# 5           5          6       Debra Holder   Left-hand bat
# 6           6          7       Daniel Smith  Right-hand bat
# 7           7          8       Mary Hensley  Right-hand bat
# 8           8          9        Amy Mathews  Right-hand bat
# 9           9         10  Heather Hernandez   Left-hand bat
#
#         booling_skill       country         dob
# 0  Right-arm offbreak     Australia  25-01-1992
# 1                 NaN  South Africa  05-04-2006
# 2                 NaN     Sri Lanka  18-06-1998
# 3      Right-arm fast   West Indies  06-04-2000
# 4    Right-arm medium     Sri Lanka  07-08-1993
# ...

# %%
data = pd.read_csv("cricket_players.csv")
data
# Out:
#      player_id          player_name    batting_hand       booling_skill  \
# 0            1          Jorge Jones  Right-hand bat  Right-arm offbreak
# 1            2          James Clark  Right-hand bat                 NaN
# 2            3       Brittney Jones  Right-hand bat                 NaN
# 3            4         Melissa Owen  Right-hand bat      Right-arm fast
# 4            5      Heather Stewart  Right-hand bat    Right-arm medium
# ..         ...                  ...             ...                 ...
# 195        196      Jamie Gutierrez  Right-hand bat    Right-arm medium
# 196        197      Holly Hernandez   Left-hand bat     Left-arm medium
# 197        198  Christopher Ramirez  Right-hand bat   Left-arm orthodox
# 198        199         Todd Skinner   Left-hand bat      Right-arm fast
# 199        200      Daniel Martinez   Left-hand bat            Legbreak
#
#           country         dob
# 0       Australia  25-01-1992
# 1    South Africa  05-04-2006
# ...

# %%
# We have to option to gain all the info of the big csv file
data.describe()
# Out:
#         player_id
# count  200.000000
# mean   100.500000
# std     57.879185
# min      1.000000
# 25%     50.750000
# 50%    100.500000
# 75%    150.250000
# max    200.000000

# %%
# We can know the data type of the individual column
data.dtypes
# Out:
# player_id         int64
# player_name      object
# batting_hand     object
# booling_skill    object
# country          object
# dob              object
# dtype: object

# %%
data = pd.read_csv("cricket_players.csv")
data
# Out:
#      player_id          player_name    batting_hand       booling_skill  \
# 0            1          Jorge Jones  Right-hand bat  Right-arm offbreak
# 1            2          James Clark  Right-hand bat                 NaN
# 2            3       Brittney Jones  Right-hand bat                 NaN
# 3            4         Melissa Owen  Right-hand bat      Right-arm fast
# 4            5      Heather Stewart  Right-hand bat    Right-arm medium
# ..         ...                  ...             ...                 ...
# 195        196      Jamie Gutierrez  Right-hand bat    Right-arm medium
# 196        197      Holly Hernandez   Left-hand bat     Left-arm medium
# 197        198  Christopher Ramirez  Right-hand bat   Left-arm orthodox
# 198        199         Todd Skinner   Left-hand bat      Right-arm fast
# 199        200      Daniel Martinez   Left-hand bat            Legbreak
#
#           country         dob
# 0       Australia  25-01-1992
# 1    South Africa  05-04-2006
# ...

# %%
# Now some extra parameter about saving the file 
data.to_csv("Result1.csv",columns=["player_name","booling_skill","country"])  # This will save only three column

# %%
# Now some extra parameter about saving the file 
data.to_csv("Result2.csv",index=False)  # This does not save the index which is show when we read the file

# %%
# Now some extra parameter about saving the file 
data.to_csv("Result3.csv",header=False)  # This does not save the header

# %%
data = pd.read_csv("cricket_players.csv")

# %%
# Some more type of accessing the data
data.columns  # It gives all the columns
# Out:
# Index(['player_id', 'player_name', 'batting_hand', 'booling_skill', 'country',
#        'dob'],
#       dtype='object')

# %%
data['player_id']  # It give the single column
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 195    196
# 196    197
# 197    198
# 198    199
# 199    200
# Name: player_id, Length: 200, dtype: int64

# %%
type(data['player_id'])  # It give the type of Series because if we find single row or single column their type is Series
# Out:
# pandas.core.series.Series

# %%
data[['player_id']]  # It also give the single column but now the type of this is change it is DataFrame
# Out:
#      player_id
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
# ..         ...
# 195        196
# 196        197
# 197        198
# 198        199
# 199        200
#
# [200 rows x 1 columns]

# %%
type(data[['player_id']])
# Out:
# pandas.core.frame.DataFrame

# %%
data['player_name']
# Out:
# 0              Jorge Jones
# 1              James Clark
# 2           Brittney Jones
# 3             Melissa Owen
# 4          Heather Stewart
#               ...
# 195        Jamie Gutierrez
# 196        Holly Hernandez
# 197    Christopher Ramirez
# 198           Todd Skinner
# 199        Daniel Martinez
# Name: player_name, Length: 200, dtype: object

# %%
# Now for the excel format data
df = pd.read_excel("cricket_players.xlsx")
df
# Out:
#      player_id          player_name    batting_hand       booling_skill  \
# 0            1          Selena York  Right-hand bat  Right-arm offbreak
# 1            2     Samuel Underwood  Right-hand bat     Left-arm medium
# 2            3         Eric Huffman   Left-hand bat            Legbreak
# 3            4          Tanya Moore  Right-hand bat       Left-arm fast
# 4            5         Jamie Bailey   Left-hand bat   Left-arm orthodox
# ..         ...                  ...             ...                 ...
# 195        196       Charles Martin   Left-hand bat      Right-arm fast
# 196        197        Sarah Parrish  Right-hand bat                 NaN
# 197        198  Katherine Henderson  Right-hand bat   Left-arm orthodox
# 198        199         Pamela Smith   Left-hand bat  Right-arm offbreak
# 199        200         David Fisher   Left-hand bat     Left-arm medium
#
#           country         dob
# 0        Pakistan  1998-08-01
# 1     West Indies  1995-04-29
# ...

# %%
# We are going to read the html pages 
data = pd.read_html("https://www.basketball-reference.com/international/players/paccelis-morlende-1.html")
data
# Out:
# [        Season             Team      League Unnamed: 3    G    MP   FG   FGA  \
#  0      2002-03            Dijon   LNB Pro A         fr   19  28.4  4.5  10.7
#  1      2003-04            Dijon   LNB Pro A         fr   33  32.0  4.7  11.5
#  2      2004-05         Benetton  Euroleague         eu   18  15.6  1.6   3.8
#  3      2004-05         Benetton         LBA         it   24  16.8  1.7   4.1
#  4      2005-06           Roseto         LBA         it    9  25.3  3.0   8.2
#  5      2005-06       Valladolid    Liga ACB         es   16  12.6  1.3   3.4
#  6      2006-07       Gravelines   LNB Pro A         fr   27  24.4  3.5   8.1
#  7      2007-08       Gravelines   LNB Pro A         fr    7  16.3  1.4   4.3
#  8      2010-11    Hyères-Toulon   LNB Pro A         fr   27  16.4  2.3   5.4
#  9      2011-12    Hyères-Toulon   LNB Pro A         fr   24  31.1  5.1  11.8
#  10     2012-13            ASVEL   LNB Pro A         fr   26  16.3  1.8   4.2
# ...

# %%
for i in range(len(data)):
    print(data[i])
# Out:
#         Season             Team      League Unnamed: 3    G    MP   FG   FGA  \
# 0      2002-03            Dijon   LNB Pro A         fr   19  28.4  4.5  10.7
# 1      2003-04            Dijon   LNB Pro A         fr   33  32.0  4.7  11.5
# 2      2004-05         Benetton  Euroleague         eu   18  15.6  1.6   3.8
# 3      2004-05         Benetton         LBA         it   24  16.8  1.7   4.1
# 4      2005-06           Roseto         LBA         it    9  25.3  3.0   8.2
# 5      2005-06       Valladolid    Liga ACB         es   16  12.6  1.3   3.4
# 6      2006-07       Gravelines   LNB Pro A         fr   27  24.4  3.5   8.1
# 7      2007-08       Gravelines   LNB Pro A         fr    7  16.3  1.4   4.3
# 8      2010-11    Hyères-Toulon   LNB Pro A         fr   27  16.4  2.3   5.4
# 9      2011-12    Hyères-Toulon   LNB Pro A         fr   24  31.1  5.1  11.8
# 10     2012-13            ASVEL   LNB Pro A         fr   26  16.3  1.8   4.2
# ...

# %%
len(data)
# Out:
# 15

# %%
data[0]
# Out:
#         Season             Team      League Unnamed: 3    G    MP   FG   FGA  \
# 0      2002-03            Dijon   LNB Pro A         fr   19  28.4  4.5  10.7
# 1      2003-04            Dijon   LNB Pro A         fr   33  32.0  4.7  11.5
# 2      2004-05         Benetton  Euroleague         eu   18  15.6  1.6   3.8
# 3      2004-05         Benetton         LBA         it   24  16.8  1.7   4.1
# 4      2005-06           Roseto         LBA         it    9  25.3  3.0   8.2
# 5      2005-06       Valladolid    Liga ACB         es   16  12.6  1.3   3.4
# 6      2006-07       Gravelines   LNB Pro A         fr   27  24.4  3.5   8.1
# 7      2007-08       Gravelines   LNB Pro A         fr    7  16.3  1.4   4.3
# 8      2010-11    Hyères-Toulon   LNB Pro A         fr   27  16.4  2.3   5.4
# 9      2011-12    Hyères-Toulon   LNB Pro A         fr   24  31.1  5.1  11.8
# 10     2012-13            ASVEL   LNB Pro A         fr   26  16.3  1.8   4.2
# ...

# %%
# We can read the csv file from the external link 
data = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/refs/heads/master/titanic.csv")
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Reading JSON
strings = """{
    "name":"Satynarayan Maurya",
    "phone_no":987654321,
    "skills":["Data Science","Machine Learning","Java Script","Python"]
}"""

# %%
import json

# %%
data = json.loads(strings)
data
# Out:
# {'name': 'Satynarayan Maurya',
#  'phone_no': 987654321,
#  'skills': ['Data Science', 'Machine Learning', 'Java Script', 'Python']}

# %%
# Now we can change this json data to the DataFrames
df = pd.DataFrame(data)
df
# Out:
#                  name   phone_no            skills
# 0  Satynarayan Maurya  987654321      Data Science
# 1  Satynarayan Maurya  987654321  Machine Learning
# 2  Satynarayan Maurya  987654321       Java Script
# 3  Satynarayan Maurya  987654321            Python

# %%
# One more way 
df = pd.DataFrame(data,columns=["skills"])
df
# Out:
#              skills
# 0      Data Science
# 1  Machine Learning
# 2       Java Script
# 3            Python

# %%
# Now about request
import requests

# %%
res = requests.get("https://api.github.com/repos/pandas-dev/pandas/issues")
res

js = res.json()
js

# %%
# Let's we want title of every dist of this list 
for i in range(len(js)):
    print(js[i]['title'])
# Out:
# IO/Stata: clarify error when input is not a Stata dataset; add GitHub…
# Support for pyarrow version under 22.0.0, hardening for AttributeError
# BUG: Series.resample failing for non-nanosecond unit that's out of bounds for nano reso
# BUG: Fix sorting behavior of DataFrame.join on list arguments
# Enable roundtripping nested dtypes through parquet and arrow
# BUG: concat warning when joining with empty and columns have different dtype
# DEPR: deprecate passing Series to Index.join
# DOC: Add Cross-reference to IO guide
# BUG: `Rolling.skew` and `Rolling.kurt` return NaN for low-variance windows
# DEPR: inconsistent string parsing in DatetimeIndex.indexer_at_time
# Warn on setitems that do not change dtype #52593
# ENH: Add an option to "nunique" to skip columns that contain unhashable values
# DOC: Remove ..versionchanged less than version 2.0
# ENH: Add `right` argument to `pandas.qcut` to support left-inclusive binning
# BUG: rolling().corr() crash with time period
# ...

# %%
# We want to convert the title and url of the dist into DataFrames
df = pd.DataFrame(js,columns=["url","title"])
df
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
# Let's Do for all the data convert the dist into DataFrame
data = pd.DataFrame(js)
data
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
# Here we notice that there is field user which is already a dist that is not converted to the DataFrames but we want to convert them
lis = []
for i in range(len(js)):
    lis.append(js[i]['user'])
userDataFrame = pd.DataFrame(lis)
userDataFrame
# Out:
#                 login         id               node_id  \
# 0             oosei25    6976037  MDQ6VXNlcjY5NzYwMzc=
# 1                smoe     207407  MDQ6VXNlcjIwNzQwNw==
# 2               phofl   61934744  MDQ6VXNlcjYxOTM0NzQ0
# 3          rhshadrach   45562402  MDQ6VXNlcjQ1NTYyNDAy
# 4               phofl   61934744  MDQ6VXNlcjYxOTM0NzQ0
# 5          rhshadrach   45562402  MDQ6VXNlcjQ1NTYyNDAy
# 6   Lakshya-Upadhyaya  196408252          U_kgDOC7TzvA
# 7            Vtwonine  203828070          U_kgDODCYrZg
# 8        Alvaro-Kothe   60141605  MDQ6VXNlcjYwMTQxNjA1
# 9        jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 10       jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 11           wjandrea   22385371  MDQ6VXNlcjIyMzg1Mzcx
# 12          mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 13          aallahyar    8081227  MDQ6VXNlcjgwODEyMjc=
# 14          kostayScr   11485271  MDQ6VXNlcjExNDg1Mjcx
# 15            ctopfel  137990064          U_kgDOCDmPsA
# ...

# %%
# The second way of doing this 
data_records = pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")
data = pd.DataFrame.Data_rec
